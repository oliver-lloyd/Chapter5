# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
trace = pd.read_csv('chapter3_trace-simple_selfloops.csv')
trace
# Out:
#       job_id                                        dataset   model  \
# 0   e9b0e007  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# 1   e9b0e007  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# 2   e9b0e007  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# 3   e9b0e007  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# 4   e9b0e007  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# ..       ...                                            ...     ...
# 95  2c7190ba  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# 96  2c7190ba  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# 97  2c7190ba  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# 98  2c7190ba  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
# 99  2c7190ba  /bp1/mrcieu1/users/fu19841/kge/data/selfloops  simple
#
#     reciprocal     job           job_type  split  epoch  avg_loss  \
# 0            0  search  negative_sampling  valid     30       NaN
# 1            0  search             KvsAll  valid    420       NaN
# 2            0  search  negative_sampling  valid     55       NaN
# 3            0  search             1vsAll  valid     40       NaN
# 4            0  search  negative_sampling  valid     25       NaN
# ..         ...     ...                ...    ...    ...       ...
# 95           0  search             KvsAll  valid     15       NaN
# 96           0  search  negative_sampling  valid     55       NaN
# 97           0  search             KvsAll  valid     55       NaN
# 98           0  search  negative_sampling  valid     55       NaN
# 99           0  search             1vsAll  valid     40       NaN
#
#     avg_penalty  ...  train.optimizer_args.lr  \
# 0           NaN  ...                 0.014126
# 1           NaN  ...                 0.000609
# 2           NaN  ...                 0.096135
# 3           NaN  ...                 0.026992
# 4           NaN  ...                 0.001301
# ..          ...  ...                      ...
# 95          NaN  ...                 0.038235
# 96          NaN  ...                 0.001809
# 97          NaN  ...                 0.000306
# 98          NaN  ...                 0.049155
# 99          NaN  ...                 0.212607
#
#    train.lr_scheduler_args.patience  lookup_embedder.dim  \
# 0                                 7                  128
# 1                                 4                   32
# 2                                10                  128
# 3                                 8                  256
# 4                                 6                   64
# ..                              ...                  ...
# 95                                8                   64
# 96                                6                  512
# 97                                4                  256
# 98                               10                   32
# 99                                5                   64
#
#     lookup_embedder.initialize lookup_embedder.regularize  \
# 0                      normal_                         lp
# 1                     uniform_                         lp
# 2               xavier_normal_                        NaN
# 3                     uniform_                         lp
# 4              xavier_uniform_                        NaN
# ..                         ...                        ...
# 95              xavier_normal_                         lp
# 96                    uniform_                         lp
# 97             xavier_uniform_                         lp
# 98                    uniform_                         lp
# 99                     normal_                        NaN
#
#     lookup_embedder.regularize_args.weighted  \
# 0                                      False
# 1                                       True
# 2                                      False
# 3                                      False
# 4                                       True
# ..                                       ...
# 95                                      True
# 96                                     False
# 97                                     False
# 98                                      True
# 99                                     False
#
#    simple.entity_embedder.regularize_weight  \
# 0                              2.171879e-13
# 1                              5.027007e-18
# 2                              4.714602e-03
# 3                              7.599944e-15
# 4                              8.060631e-11
# ..                                      ...
# 95                             7.062948e-07
# 96                             2.380107e-12
# 97                             3.696079e-05
# 98                             1.102647e-18
# 99                             8.311538e-14
#
#    simple.relation_embedder.regularize_weight simple.entity_embedder.dropout  \
# 0                                2.937767e-05                       0.262571
# 1                                4.680830e-19                       0.166188
# 2                                1.530229e-06                       0.492019
# 3                                4.774237e-10                       0.015407
# 4                                7.190952e-18                       0.330292
# ..                                        ...                            ...
# 95                               4.884917e-14                       0.452988
# 96                               1.181214e-02                       0.142711
# 97                               3.226873e-06                       0.353729
# 98                               8.570622e-13                       0.054479
# 99                               5.873069e-08                       0.391829
#
#     simple.relation_embedder.dropout
# 0                           0.244941
# 1                           0.035968
# 2                           0.318780
# 3                           0.071647
# 4                           0.292874
# ..                               ...
# 95                          0.300773
# 96                          0.079373
# 97                          0.342242
# 98                          0.059381
# 99                          0.221479
#
# [100 rows x 29 columns]

# %%
trace.dtypes
# Out:
# job_id                                         object
# dataset                                        object
# model                                          object
# reciprocal                                      int64
# job                                            object
# job_type                                       object
# split                                          object
# epoch                                           int64
# avg_loss                                      float64
# avg_penalty                                   float64
# avg_cost                                      float64
# metric_name                                    object
# metric                                        float64
# child_folder                                    int64
# child_job_id                                   object
# train.batch_size                                int64
# train.type                                     object
# train.optimizer                                object
# train.loss                                     object
# train.optimizer_args.lr                       float64
# train.lr_scheduler_args.patience                int64
# lookup_embedder.dim                             int64
# lookup_embedder.initialize                     object
# lookup_embedder.regularize                     object
# lookup_embedder.regularize_args.weighted         bool
# simple.entity_embedder.regularize_weight      float64
# simple.relation_embedder.regularize_weight    float64
# simple.entity_embedder.dropout                float64
# simple.relation_embedder.dropout              float64
# dtype: object

# %%
def plot(hyperparameter):
    response_var = 'metric'
    dtype = trace[hyperparameter].dtype
    if dtype == object:
        plotter = sns.barplot
    else:
        plotter = sns.lineplot
    plotter(trace, x=hyperparameter, y=response_var)
    plt.title(hyperparameter)
    plt.xlabel(hyperparameter)
    if 'regularize_weight' in hyperparameter or 'lr' in hyperparameter:
        plt.xscale('log')
    plt.show()

# %%
to_plot = ['epoch'] + list(trace.columns[15:])
for col in to_plot:
    plot(col)

# %% [markdown]
# # Immediate conclusions
#
# - Remove Adadelta as an option for optimizer
# - Remove 'se' as option for loss function
# - Remove 32/64 dim as options in embeddings shape
